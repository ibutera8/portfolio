# %% [markdown]
# # **Análisis de Datos: Mundiales de la FIFA**
#
# La idea de este notebook es analizar mundiales de la FIFA, los países con más goles, los mejores arqueros, etc.

# %%
#importamos las librerias que de entrada sabemos que las vamos a usar

import numpy as np
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')

fpartidos = '/content/drive/My Drive/LaboDatos2022/PrimeraEjercitacion/WorldCupMatches.csv'
fjugadores = '/content/drive/My Drive/LaboDatos2022/PrimeraEjercitacion/WorldCupPlayers.csv'
# Out:
# Mounted at /content/drive

# %%
#montamos los dataframes para poder analizarlos

csv_partidos = pd.read_csv(fpartidos)
csv_jugadores = pd.read_csv(fjugadores)

df_p = pd.DataFrame(csv_partidos)
df_j = pd.DataFrame(csv_jugadores)

# %%
#print(df_p.columns)  #analizamos por arriba los df para ver con que estamos tratando
#print(df_j.columns)

df_p
# Out:
#         Year              Datetime    Stage         Stadium         City  \
# 0     1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1     1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2     1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3     1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4     1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# ...      ...                   ...      ...             ...          ...
# 4567     NaN                   NaN      NaN             NaN          NaN
# 4568     NaN                   NaN      NaN             NaN          NaN
# 4569     NaN                   NaN      NaN             NaN          NaN
# 4570     NaN                   NaN      NaN             NaN          NaN
# 4571     NaN                   NaN      NaN             NaN          NaN
#
#      Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0            France              4.0              1.0         Mexico
# 1               USA              3.0              0.0        Belgium
# 2        Yugoslavia              2.0              1.0         Brazil
# 3           Romania              3.0              1.0           Peru
# 4         Argentina              1.0              0.0         France
# ...             ...              ...              ...            ...
# 4567            NaN              NaN              NaN            NaN
# 4568            NaN              NaN              NaN            NaN
# 4569            NaN              NaN              NaN            NaN
# 4570            NaN              NaN              NaN            NaN
# 4571            NaN              NaN              NaN            NaN
#
#      Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                        4444.0                   3.0                   0.0
# 1                       18346.0                   2.0                   0.0
# 2                       24059.0                   2.0                   0.0
# 3                        2549.0                   1.0                   0.0
# 4                       23409.0                   0.0                   0.0
# ...             ...         ...                   ...                   ...
# 4567            NaN         NaN                   NaN                   NaN
# 4568            NaN         NaN                   NaN                   NaN
# 4569            NaN         NaN                   NaN                   NaN
# 4570            NaN         NaN                   NaN                   NaN
# 4571            NaN         NaN                   NaN                   NaN
#
#                      Referee               Assistant 1  \
# 0     LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1          MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2        TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3      WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4        REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
# ...                      ...                       ...
# 4567                     NaN                       NaN
# 4568                     NaN                       NaN
# 4569                     NaN                       NaN
# 4570                     NaN                       NaN
# 4571                     NaN                       NaN
#
#                      Assistant 2  RoundID  MatchID Home Team Initials  \
# 0            REGO Gilberto (BRA)    201.0   1096.0                FRA
# 1          WARNKEN Alberto (CHI)    201.0   1090.0                USA
# 2            BALWAY Thomas (FRA)    201.0   1093.0                YUG
# 3       MATEUCCI Francisco (URU)    201.0   1098.0                ROU
# 4     RADULESCU Constantin (ROU)    201.0   1085.0                ARG
# ...                          ...      ...      ...                ...
# 4567                         NaN      NaN      NaN                NaN
# 4568                         NaN      NaN      NaN                NaN
# 4569                         NaN      NaN      NaN                NaN
# 4570                         NaN      NaN      NaN                NaN
# 4571                         NaN      NaN      NaN                NaN
#
#      Away Team Initials
# 0                   MEX
# 1                   BEL
# 2                   BRA
# 3                   PER
# 4                   FRA
# ...                 ...
# 4567                NaN
# 4568                NaN
# 4569                NaN
# 4570                NaN
# 4571                NaN
#
# [4572 rows x 20 columns]

# %%
#df_p
#examinando el df de los partidos vi q habia muchos NaN y valores repetidos en MatchID, asi q los droppeo
df_p.dropna(inplace=True)
df_p.drop_duplicates(subset=['MatchID'], inplace=True)
df_p['MatchID'].value_counts()
# Out:
# 1096.0         1
# 43950048.0     1
# 8758.0         1
# 8759.0         1
# 8762.0         1
#               ..
# 2197.0         1
# 2246.0         1
# 2224.0         1
# 2408.0         1
# 300186497.0    1
# Name: MatchID, Length: 835, dtype: int64

# %%
#aca creamos una nueva columna con la cantidad total de goles que fueron anotados en cada partido

df_p1 = df_p.copy()
df_p1['Total Goals in that Match'] = df_p['Home Team Goals'] + df_p['Away Team Goals'] + df_p['Half-time Away Goals'] + df_p['Half-time Home Goals']

# %%
def avg_goals_year(df, year):                   #funcion que nos calcula la cantidad de goles promedio por año dado un df_p y un año
  df2 = df[df['Year'] == year]
  sum = df2['Total Goals in that Match'].sum()
  avg = sum/df2.size
  return avg

def total_goals_year(df, year):
  df2 = df[df['Year'] == year]
  total = df2['Total Goals in that Match'].sum()
  return total

#total_goals_year(df_p1, 2014)  #->aca calculamos que eran 200 goles para el año 2014 (ver mas adelante)

# %%
l_years = [i for i in df_p1['Year'].unique()]   #armamos una lista con los años de mundiales para despues poder armar un dict
#l_years
avg_dict = dict()

for year in l_years:
  avg_dict[avg_goals_year(df_p1, year)] = year.astype(int)   #aca tenemos el dict con key=avg y vals=years, podemos "ordenarlo" y sacar el histograma

#creamos las columnas como Series
avg_year = pd.Series(avg_dict.keys())
year = pd.Series(avg_dict.values())

#creamos el nuevo df con las columnas que hicimos ahi arriba
df_p11 = pd.DataFrame()
df_p11['Year'] = year
df_p11['Avg'] = avg_year

df_p11 = df_p11.sort_values('Avg', ascending=False)  #aca lo ordenamos, ya listo para analizar
df_p11
# Out:
#     Year       Avg
# 4   1954  0.364469
# 2   1938  0.301587
# 3   1950  0.279221
# 1   1934  0.277311
# 0   1930  0.269841
# 5   1958  0.244898
# 7   1966  0.191964
# 6   1978  0.190476
# 8   1970  0.188988
# 13  1994  0.185897
# 9   1974  0.177945
# 10  1982  0.177656
# 14  1998  0.176339
# 18  2014  0.174603
# 15  2002  0.168155
# 11  1986  0.164835
# 16  2006  0.158482
# 17  2010  0.150298
# 12  1990  0.134615

# %%
import matplotlib.pyplot as plt

#creamos nuestras listas con datos, por alguna razon queda mejor que si usamos el df directo
x = [str(mundial) for mundial in df_p11['Year']]
y = [avg for avg in df_p11['Avg']]

plt.figure(figsize=(15,7))
plt.bar(x, height=y, width=0.8, color='r')


plt.xlabel("Mundial")
plt.ylabel("Promedio de goles")
plt.title("Grafico Ejercicio 1: Goles promedio por Mundial")
plt.show()  ##me faltaria nomas ordenarlo de izquiera a derecha,pero ni siquiera esta muy claro en la consigna. asi q me voy a dormir pr ahora

# %%
# EJERCICIO 2
#primero chusmeamos que forma tienen los datos de la columna win conditions

df_p['Win conditions'].value_counts()
# Out:
#                                                  779
# Italy win after extra time                         5
# Argentina win after extra time                     3
# Win on Golden Goal                                 3
# England win after extra time                       3
# France win after extra time                        2
# France win on penalties (3 - 4)                    2
# Brazil win on penalties (3 - 2)                    2
# Belgium win after extra time                       2
# Paraguay win on penalties (5 - 3)                  1
# Uruguay win on penalties (4 - 2)                   1
# Ghana win after extra time                         1
# Spain win after extra time                         1
# Germany win after extra time                       1
# Italy win on penalties (5 - 3)                     1
# Portugal win on penalties (1 - 3)                  1
# Argentina win on penalties (2 - 4)                 1
# Germany win on penalties (4 - 2)                   1
# Ukraine win on penalties (0 - 3)                   1
# Korea Republic win on penalties (3 - 5)            1
# Netherlands win on penalties (4 - 3)               1
# Spain win on penalties (3 - 2)                     1
# Brazil win on penalties (4 - 2)                    1
# Argentina win on penalties (4 - 3)                 1
#  win on penalties (3 - 4)                          1
# Sweden win on penalties (4 - 5)                    1
# Bulgaria win on penalties (1 - 3)                  1
# Brazil win after extra time                        1
# Czechoslovakia win after extra time                1
# Hungary win after extra time                       1
# Northern Ireland win after extra time              1
# Germany FR win after extra time                    1
# Uruguay win after extra time                       1
#  win on penalties (5 - 4)                          1
# Germany FR win on penalties (4 - 1)                1
# Belgium win on penalties (4 - 5)                   1
# Cameroon win after extra time                      1
# Republic of Ireland win on penalties (5 - 4)       1
# Yugoslavia win after extra time                    1
#  win on penalties (2 - 3)                          1
# Austria win after extra time                       1
#  win on penalties (4 - 3)                          1
# Costa Rica win on penalties (5 - 3)                1
# Name: Win conditions, dtype: int64

# %%
#vemos que hay valores de 'Win conditions' en los que hay ganadores por penales, pero no nos dice quien
#inspeccionemos el df_p en esas filas especificamente

df_p[df_p['Win conditions'].str.startswith(' win')]
# Out:
#        Year              Datetime           Stage                Stadium  \
# 357  1982.0  08 Jul 1982 - 21:00      Semi-finals  Ramon Sanchez Pizjuan
# 456  1990.0  30 Jun 1990 - 17:00   Quarter-finals               Comunale
# 460  1990.0  03 Jul 1990 - 20:00      Semi-finals              San Paolo
# 461  1990.0  04 Jul 1990 - 20:00      Semi-finals      Stadio delle Alpi
#
#           City Home Team Name  Home Team Goals  Away Team Goals  \
# 357   Seville      Germany FR              3.0              3.0
# 456  Florence      Yugoslavia              0.0              0.0
# 460    Naples           Italy              1.0              1.0
# 461     Turin      Germany FR              1.0              1.0
#
#     Away Team Name              Win conditions  Attendance  \
# 357         France   win on penalties (5 - 4)      70000.0
# 456      Argentina   win on penalties (2 - 3)      38971.0
# 460      Argentina   win on penalties (3 - 4)      59978.0
# 461        England   win on penalties (4 - 3)      62628.0
#
#      Half-time Home Goals  Half-time Away Goals                    Referee  \
# 357                   0.0                   0.0       CORVER Charles (NED)
# 456                   0.0                   0.0  ROETHLISBERGER Kurt (SUI)
# 460                   0.0                   0.0       VAUTROT Michel (FRA)
# 461                   0.0                   0.0    RAMIZ WRIGHT Jose (BRA)
#
#                   Assistant 1                Assistant 2  RoundID  MatchID  \
# 357        GALLER Bruno (SUI)     VALENTINE Robert (SCO)    295.0    914.0
# 456         JOUINI Neji (TUN)       HANSAL Mohamed (ALG)    751.0     31.0
# 460  LISTKIEWICZ Michal (POL)      MIKKELSEN Peter (DEN)   3464.0     28.0
# 461        QUINIOU Joel (FRA)  PEREZ HOYOS Armando (COL)   3464.0    159.0
#
#     Home Team Initials Away Team Initials
# 357                FRG                FRA
# 456                YUG                ARG
# 460                ITA                ARG
# 461                FRG                ENG

# %%
#podriamos definir una funcion general, pero como son solo 4 filas para corregir, elijo la simplicidad de no pensar la funcion general que haría esto:
# vemos que en cada partido el 'win on penalties (X-Y)' el X es la cantidad de goles del home team, y el Y es el away team
#asi sabemos facilmente quein corresponde que gane en cada caso

df_p2 = df_p.copy()


df_p2['Win conditions'].loc[357] = 'Germany FR win on penalties (5 - 4)'
df_p2['Win conditions'].loc[456] = 'Argentina win on penalties (2 - 3)'
df_p2['Win conditions'].loc[460] = 'Argentina win on penalties (3 - 4)'
df_p2['Win conditions'].loc[461] = 'Germany FR win on penalties (4 - 3)'

df_p2[df_p['Win conditions'].str.startswith(' win')] #verificamos si funcionó
# Out:
# <ipython-input-11-87ff641a9952>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_p2['Win conditions'].loc[357] = 'Germany FR win on penalties (5 - 4)'
# <ipython-input-11-87ff641a9952>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_p2['Win conditions'].loc[456] = 'Argentina win on penalties (2 - 3)'
# <ipython-input-11-87ff641a9952>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_p2['Win conditions'].loc[460] = 'Argentina win on penalties (3 - 4)'
# <ipython-input-11-87ff641a9952>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_p2['Win conditions'].loc[461] = 'Germany FR win on penalties (4 - 3)'
#        Year              Datetime           Stage                Stadium  \
# 357  1982.0  08 Jul 1982 - 21:00      Semi-finals  Ramon Sanchez Pizjuan
# 456  1990.0  30 Jun 1990 - 17:00   Quarter-finals               Comunale
# 460  1990.0  03 Jul 1990 - 20:00      Semi-finals              San Paolo
# 461  1990.0  04 Jul 1990 - 20:00      Semi-finals      Stadio delle Alpi
#
#           City Home Team Name  Home Team Goals  Away Team Goals  \
# 357   Seville      Germany FR              3.0              3.0
# 456  Florence      Yugoslavia              0.0              0.0
# 460    Naples           Italy              1.0              1.0
# 461     Turin      Germany FR              1.0              1.0
#
#     Away Team Name                       Win conditions  Attendance  \
# 357         France  Germany FR win on penalties (5 - 4)     70000.0
# 456      Argentina   Argentina win on penalties (2 - 3)     38971.0
# 460      Argentina   Argentina win on penalties (3 - 4)     59978.0
# 461        England  Germany FR win on penalties (4 - 3)     62628.0
#
#      Half-time Home Goals  Half-time Away Goals                    Referee  \
# 357                   0.0                   0.0       CORVER Charles (NED)
# 456                   0.0                   0.0  ROETHLISBERGER Kurt (SUI)
# 460                   0.0                   0.0       VAUTROT Michel (FRA)
# 461                   0.0                   0.0    RAMIZ WRIGHT Jose (BRA)
#
#                   Assistant 1                Assistant 2  RoundID  MatchID  \
# 357        GALLER Bruno (SUI)     VALENTINE Robert (SCO)    295.0    914.0
# 456         JOUINI Neji (TUN)       HANSAL Mohamed (ALG)    751.0     31.0
# 460  LISTKIEWICZ Michal (POL)      MIKKELSEN Peter (DEN)   3464.0     28.0
# 461        QUINIOU Joel (FRA)  PEREZ HOYOS Armando (COL)   3464.0    159.0
#
#     Home Team Initials Away Team Initials
# 357                FRG                FRA
# 456                YUG                ARG
# 460                ITA                ARG
# 461                FRG                ENG

# %%
#nos creamos una lista con todos los paises que ganaron partidos por penales

l_penales = list()

for condition in df_p2['Win conditions']:
  if 'penalties' in condition:
    l_penales.append(condition)
#l_penales

for i in range(len(l_penales)):
  l_penales[i] = (l_penales[i].split('win', 1)[0]).rstrip()    #aca modificamos la lista de partidos ganados por penales, solo nos interesa el pais ganador

l_penales
# Out:
# ['Germany FR',
#  'France',
#  'Germany FR',
#  'Belgium',
#  'Republic of Ireland',
#  'Argentina',
#  'Argentina',
#  'Germany FR',
#  'Bulgaria',
#  'Sweden',
#  'Brazil',
#  'Argentina',
#  'France',
#  'Brazil',
#  'Spain',
#  'Korea Republic',
#  'Ukraine',
#  'Germany',
#  'Portugal',
#  'Italy',
#  'Paraguay',
#  'Uruguay',
#  'Brazil',
#  'Argentina',
#  'Netherlands',
#  'Costa Rica']

# %%
#ahora nos creamos un diccionario que haga un conteo de la cantidad de veces que un pais haya ganado por penales:
#estamos asumiendo que Germany FR y Germany son dos paises distintos, pues son dos estados, sociedades, y sistemas politicos distintos

count_penales = dict()   #diccionario vacio

for country in l_penales:
  try:
    count_penales[country] += 1    #si la key ya esta en el dict, le sumamos 1 al value
  except:
    count_penales[country] = 1     #si la key no estaba en el dict, la creamos con value 1

count_penales
# Out:
# {'Germany FR': 3,
#  'France': 2,
#  'Belgium': 1,
#  'Republic of Ireland': 1,
#  'Argentina': 4,
#  'Bulgaria': 1,
#  'Sweden': 1,
#  'Brazil': 3,
#  'Spain': 1,
#  'Korea Republic': 1,
#  'Ukraine': 1,
#  'Germany': 1,
#  'Portugal': 1,
#  'Italy': 1,
#  'Paraguay': 1,
#  'Uruguay': 1,
#  'Netherlands': 1,
#  'Costa Rica': 1}

# %%
#creamos un dtaframe para poder ordenar los valores, sino no puedo ordenar el dict para que quede lindo el grafico

df_p21 = pd.DataFrame()

df_p21['Country'] = pd.Series([i for i in count_penales.keys()])
df_p21['Matches won by penalties'] = pd.Series([i for i in count_penales.values()])

df_p21.sort_values(by='Matches won by penalties', ascending=False, inplace=True)
df_p21
# Out:
#                 Country  Matches won by penalties
# 4             Argentina                         4
# 0            Germany FR                         3
# 7                Brazil                         3
# 1                France                         2
# 11              Germany                         1
# 16          Netherlands                         1
# 15              Uruguay                         1
# 14             Paraguay                         1
# 13                Italy                         1
# 12             Portugal                         1
# 9        Korea Republic                         1
# 10              Ukraine                         1
# 8                 Spain                         1
# 6                Sweden                         1
# 5              Bulgaria                         1
# 3   Republic of Ireland                         1
# 2               Belgium                         1
# 17           Costa Rica                         1

# %%
#ahora que ya tenemos la info que queremos, hagamos el grafico:

x = [str(i) for i in df_p21['Country']]
y = [i for i in df_p21['Matches won by penalties']]

plt.figure(figsize=(25,7))
plt.bar(x, height=y, width=0.8, color='b')

plt.xlabel("Paises")
plt.ylabel("Cantidad de partidos que ganaron por penales")
plt.title("Grafico Ejercicio 2: Cantidad de veces que los paises ganaron por penales")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#ahora viene la parte mas dificil del ejercicio, averiguar quien es el arquero que más penales atajó.
#vamos a tener que mergear ambos df, asi que chusmeemos quienes son las columnas a ver donde hacer el join

print(df_p2.columns)
print(df_j.columns)
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')
# Index(['RoundID', 'MatchID', 'Team Initials', 'Coach Name', 'Line-up',
#        'Shirt Number', 'Player Name', 'Position', 'Event'],
#       dtype='object')

# %%
df_j.drop_duplicates(inplace=True)
df_j2 = df_j.copy()

# %%
#hacemos el join de ambos df en uno unico en base al match id
df_2 = df_p2.merge(df_j2, how='inner', on='MatchID')

df_2.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID_x', 'MatchID', 'Home Team Initials', 'Away Team Initials',
#        'RoundID_y', 'Team Initials', 'Coach Name', 'Line-up', 'Shirt Number',
#        'Player Name', 'Position', 'Event'],
#       dtype='object')

# %%
#pero solo me interesan las siguientes columnas
cols_ej2 = ['Home Team Initials', 'Away Team Initials', 'Home Team Name', 'Away Team Name','Win conditions', 'Player Name', 'Position', 'Team Initials']

df_21 = df_2[cols_ej2] #filtramos el df para obtener solo las columnas que nos interesan
df_21 = df_21[df_21['Win conditions'].str.contains("penalties")] #filtramos las filas, solo queremos las de los penales
df_21 = df_21[df_21['Position'] == "GK"] #filtramos las filas, solo queremos los jugadores que son GK

#hay algo importante que remarcar, por partido tenemos dos filas: la del equipo ganador y la del equpo perdedor, tendriamos que ver de conseguir solo las de los ganadores
df_21
# Out:
#       Home Team Initials Away Team Initials Home Team Name Away Team Name  \
# 15457                FRG                FRA     Germany FR         France
# 15458                FRG                FRA     Germany FR         France
# 17525                BRA                FRA         Brazil         France
# 17526                BRA                FRA         Brazil         France
# 17569                FRG                MEX     Germany FR         Mexico
# ...                  ...                ...            ...            ...
# 36865                CRC                GRE     Costa Rica         Greece
# 36886                CRC                GRE     Costa Rica         Greece
# 36887                CRC                GRE     Costa Rica         Greece
# 36888                CRC                GRE     Costa Rica         Greece
# 36889                CRC                GRE     Costa Rica         Greece
#
#                              Win conditions        Player Name Position  \
# 15457   Germany FR win on penalties (5 - 4)  Harald SCHUMACHER       GK
# 15458   Germany FR win on penalties (5 - 4)    Jean Luc ETTORI       GK
# 17525      France win on penalties (3 - 4)              CARLOS       GK
# 17526      France win on penalties (3 - 4)           Joel BATS       GK
# 17569  Germany FR win on penalties (4 - 1)   Harald SCHUMACHER       GK
# ...                                     ...                ...      ...
# 36865  Costa Rica win on penalties (5 - 3)            KARNEZIS       GK
# 36886  Costa Rica win on penalties (5 - 3)        PEMBERTON P.       GK
# 36887  Costa Rica win on penalties (5 - 3)              GLYKOS       GK
# 36888  Costa Rica win on penalties (5 - 3)       CAMBRONERO D.       GK
# 36889  Costa Rica win on penalties (5 - 3)              KAPINO       GK
#
#       Team Initials
# 15457           FRG
# 15458           FRA
# 17525           BRA
# 17526           FRA
# 17569           FRG
# ...             ...
# 36865           GRE
# 36886           CRC
# 36887           GRE
# 36888           CRC
# 36889           GRE
#
# [81 rows x 8 columns]

# %%
def agrego_winnercountry(df):  #defino una fn que me crea una columna en cada partido anunciando quien fue el pais ganador
  df['Winner Country'] = pd.Series()
  for i in df.index:
    wc = df['Win conditions'].loc[i]
    hn = df['Home Team Name'].loc[i]
    an = df['Away Team Name'].loc[i]

    if hn in wc:
      df['Winner Country'].loc[i] = hn
    elif an in wc:
      df['Winner Country'].loc[i] = an

  return None

def agrego_winnerinitials(df): #hace lo mismo pero con las iniciales del pais ganador
    df['Winner Initials'] = pd.Series()
    for i in df.index:
      hi = df['Home Team Initials'].loc[i]
      ai = df['Away Team Initials'].loc[i]

      if df['Winner Country'].loc[i] == df['Home Team Name'].loc[i]:
        df['Winner Initials'].loc[i] = hi
      else:
        df['Winner Initials'].loc[i] = ai

    return None #void

# %%
agrego_winnercountry(df_21)
agrego_winnerinitials(df_21)
df_21
# Out:
# <ipython-input-20-417f7684f82d>:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df['Winner Country'] = pd.Series()
# <ipython-input-20-417f7684f82d>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Winner Country'].loc[i] = hn
# <ipython-input-20-417f7684f82d>:16: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df['Winner Initials'] = pd.Series()
# <ipython-input-20-417f7684f82d>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Winner Initials'].loc[i] = hi
#       Home Team Initials Away Team Initials Home Team Name Away Team Name  \
# 15457                FRG                FRA     Germany FR         France
# 15458                FRG                FRA     Germany FR         France
# 17525                BRA                FRA         Brazil         France
# 17526                BRA                FRA         Brazil         France
# 17569                FRG                MEX     Germany FR         Mexico
# ...                  ...                ...            ...            ...
# 36865                CRC                GRE     Costa Rica         Greece
# 36886                CRC                GRE     Costa Rica         Greece
# 36887                CRC                GRE     Costa Rica         Greece
# 36888                CRC                GRE     Costa Rica         Greece
# 36889                CRC                GRE     Costa Rica         Greece
#
#                              Win conditions        Player Name Position  \
# 15457   Germany FR win on penalties (5 - 4)  Harald SCHUMACHER       GK
# 15458   Germany FR win on penalties (5 - 4)    Jean Luc ETTORI       GK
# 17525      France win on penalties (3 - 4)              CARLOS       GK
# 17526      France win on penalties (3 - 4)           Joel BATS       GK
# 17569  Germany FR win on penalties (4 - 1)   Harald SCHUMACHER       GK
# ...                                     ...                ...      ...
# 36865  Costa Rica win on penalties (5 - 3)            KARNEZIS       GK
# 36886  Costa Rica win on penalties (5 - 3)        PEMBERTON P.       GK
# 36887  Costa Rica win on penalties (5 - 3)              GLYKOS       GK
# 36888  Costa Rica win on penalties (5 - 3)       CAMBRONERO D.       GK
# 36889  Costa Rica win on penalties (5 - 3)              KAPINO       GK
#
#       Team Initials Winner Country Winner Initials
# 15457           FRG     Germany FR             FRG
# 15458           FRA     Germany FR             FRG
# 17525           BRA         France             FRA
# 17526           FRA         France             FRA
# 17569           FRG     Germany FR             FRG
# ...             ...            ...             ...
# 36865           GRE     Costa Rica             CRC
# 36886           CRC     Costa Rica             CRC
# 36887           GRE     Costa Rica             CRC
# 36888           CRC     Costa Rica             CRC
# 36889           GRE     Costa Rica             CRC
#
# [81 rows x 10 columns]

# %%
# ahora tenemos un df con toda la info que necesitamos (de hecho tiene ifno de sobra :V)

df_21 = df_21[df_21['Team Initials'] == df_21['Winner Initials']] #nos quedamos solo con las filas que tienen al equipo ganador

df_21 #este si que es el dataframe que queriamos, tiene todos los nombres de arqueros que ganaron los partidos por penales
# Out:
#       Home Team Initials Away Team Initials Home Team Name  \
# 15457                FRG                FRA     Germany FR
# 17526                BRA                FRA         Brazil
# 17569                FRG                MEX     Germany FR
# 17614                ESP                BEL          Spain
# 19816                YUG                ARG     Yugoslavia
# 19993                ITA                ARG          Italy
# 20015                ITA                ARG          Italy
# 20017                ITA                ARG          Italy
# 20019                ITA                ARG          Italy
# 20037                FRG                ENG     Germany FR
# 22239                ROU                SWE        Romania
# 22414                BRA                ITA         Brazil
# 24878                ARG                ENG      Argentina
# 24923                ITA                FRA          Italy
# 25098                BRA                NED         Brazil
# 27574                ESP                IRL          Spain
# 27989                ESP                KOR          Spain
# 30656                SUI                UKR    Switzerland
# 30678                SUI                UKR    Switzerland
# 30680                SUI                UKR    Switzerland
# 30793                GER                ARG        Germany
# 30886                ENG                POR        England
# 31115                ITA                FRA          Italy
# 33666                PAR                JPN       Paraguay
# 33668                PAR                JPN       Paraguay
# 33782                URU                GHA        Uruguay
# 33804                URU                GHA        Uruguay
# 33806                URU                GHA        Uruguay
# 36312                BRA                CHI         Brazil
# 36334                BRA                CHI         Brazil
# 36336                BRA                CHI         Brazil
# 36681                NED                ARG    Netherlands
# 36703                NED                ARG    Netherlands
# 36705                NED                ARG    Netherlands
# 36726                NED                CRC    Netherlands
# 36748                NED                CRC    Netherlands
# 36750                NED                CRC    Netherlands
# 36864                CRC                GRE     Costa Rica
# 36886                CRC                GRE     Costa Rica
# 36888                CRC                GRE     Costa Rica
#
#                 Away Team Name                            Win conditions  \
# 15457                   France       Germany FR win on penalties (5 - 4)
# 17526                   France          France win on penalties (3 - 4)
# 17569                   Mexico      Germany FR win on penalties (4 - 1)
# 17614                  Belgium         Belgium win on penalties (4 - 5)
# 19816                Argentina        Argentina win on penalties (2 - 3)
# 19993                Argentina        Argentina win on penalties (3 - 4)
# 20015                Argentina        Argentina win on penalties (3 - 4)
# 20017                Argentina        Argentina win on penalties (3 - 4)
# 20019                Argentina        Argentina win on penalties (3 - 4)
# 20037                  England       Germany FR win on penalties (4 - 3)
# 22239                   Sweden          Sweden win on penalties (4 - 5)
# 22414                    Italy          Brazil win on penalties (3 - 2)
# 24878                  England       Argentina win on penalties (4 - 3)
# 24923                   France          France win on penalties (3 - 4)
# 25098              Netherlands          Brazil win on penalties (4 - 2)
# 27574  rn">Republic of Ireland           Spain win on penalties (3 - 2)
# 27989           Korea Republic  Korea Republic win on penalties (3 - 5)
# 30656                  Ukraine         Ukraine win on penalties (0 - 3)
# 30678                  Ukraine         Ukraine win on penalties (0 - 3)
# 30680                  Ukraine         Ukraine win on penalties (0 - 3)
# 30793                Argentina         Germany win on penalties (4 - 2)
# 30886                 Portugal        Portugal win on penalties (1 - 3)
# 31115                   France           Italy win on penalties (5 - 3)
# 33666                    Japan        Paraguay win on penalties (5 - 3)
# 33668                    Japan        Paraguay win on penalties (5 - 3)
# 33782                    Ghana         Uruguay win on penalties (4 - 2)
# 33804                    Ghana         Uruguay win on penalties (4 - 2)
# 33806                    Ghana         Uruguay win on penalties (4 - 2)
# 36312                    Chile          Brazil win on penalties (3 - 2)
# 36334                    Chile          Brazil win on penalties (3 - 2)
# 36336                    Chile          Brazil win on penalties (3 - 2)
# 36681                Argentina       Argentina win on penalties (2 - 4)
# 36703                Argentina       Argentina win on penalties (2 - 4)
# 36705                Argentina       Argentina win on penalties (2 - 4)
# 36726               Costa Rica     Netherlands win on penalties (4 - 3)
# 36748               Costa Rica     Netherlands win on penalties (4 - 3)
# 36750               Costa Rica     Netherlands win on penalties (4 - 3)
# 36864                   Greece      Costa Rica win on penalties (5 - 3)
# 36886                   Greece      Costa Rica win on penalties (5 - 3)
# 36888                   Greece      Costa Rica win on penalties (5 - 3)
#
#               Player Name Position Team Initials  Winner Country  \
# 15457   Harald SCHUMACHER       GK           FRG      Germany FR
# 17526           Joel BATS       GK           FRA          France
# 17569   Harald SCHUMACHER       GK           FRG      Germany FR
# 17614    Jean Marie PFAFF       GK           BEL         Belgium
# 19816    Sergio GOYCOCHEA       GK           ARG       Argentina
# 19993    Sergio GOYCOCHEA       GK           ARG       Argentina
# 20015       Angel COMIZZO       GK           ARG       Argentina
# 20017        Nery PUMPIDO       GK           ARG       Argentina
# 20019  Fabian CANCELARICH       GK           ARG       Argentina
# 20037        Bodo ILLGNER       GK           FRG      Germany FR
# 22239      Thomas RAVELLI       GK           SWE          Sweden
# 22414            TAFFAREL       GK           BRA          Brazil
# 24878          Carlos ROA       GK           ARG       Argentina
# 24923      Fabien BARTHEZ       GK           FRA          France
# 25098            TAFFAREL       GK           BRA          Brazil
# 27574            CASILLAS       GK           ESP           Spain
# 27989             W J LEE       GK           KOR  Korea Republic
# 30656         SHOVKOVSKYI       GK           UKR         Ukraine
# 30678              PYATOV       GK           UKR         Ukraine
# 30680               SHUST       GK           UKR         Ukraine
# 30793             LEHMANN       GK           GER         Germany
# 30886             RICARDO       GK           POR        Portugal
# 31115              BUFFON       GK           ITA           Italy
# 33666          D. BARRETO       GK           PAR        Paraguay
# 33668           BOBADILLA       GK           PAR        Paraguay
# 33782             MUSLERA       GK           URU         Uruguay
# 33804            CASTILLO       GK           URU         Uruguay
# 33806               SILVA       GK           URU         Uruguay
# 36312         JULIO CESAR       GK           BRA          Brazil
# 36334           JEFFERSON       GK           BRA          Brazil
# 36336              VICTOR       GK           BRA          Brazil
# 36681              ROMERO       GK           ARG       Argentina
# 36703               ORION       GK           ARG       Argentina
# 36705             ANDUJAR       GK           ARG       Argentina
# 36726           CILLESSEN       GK           NED     Netherlands
# 36748                VORM       GK           NED     Netherlands
# 36750                KRUL       GK           NED     Netherlands
# 36864            NAVAS K.       GK           CRC      Costa Rica
# 36886        PEMBERTON P.       GK           CRC      Costa Rica
# 36888       CAMBRONERO D.       GK           CRC      Costa Rica
#
#       Winner Initials
# 15457             FRG
# 17526             FRA
# 17569             FRG
# 17614             BEL
# 19816             ARG
# 19993             ARG
# 20015             ARG
# 20017             ARG
# 20019             ARG
# 20037             FRG
# 22239             SWE
# 22414             BRA
# 24878             ARG
# 24923             FRA
# 25098             BRA
# 27574             ESP
# 27989             KOR
# 30656             UKR
# 30678             UKR
# 30680             UKR
# 30793             GER
# 30886             POR
# 31115             ITA
# 33666             PAR
# 33668             PAR
# 33782             URU
# 33804             URU
# 33806             URU
# 36312             BRA
# 36334             BRA
# 36336             BRA
# 36681             ARG
# 36703             ARG
# 36705             ARG
# 36726             NED
# 36748             NED
# 36750             NED
# 36864             CRC
# 36886             CRC
# 36888             CRC

# %%
# y ahora pedimos el maximo.
#de todos modos, si uno inspecciona df_21 vemos que son varios los arqueros que ganaron 2 partidos por penales :(

#df_21['Player Name'].value_counts()


arquero = df_21['Player Name'].iloc[df_21['Player Name'].value_counts().max()]   #pedimos el max
print('El arquero que mas partidos ganó por penales es', arquero) #printeamos la respuesta
# Out:
# El arquero que mas partidos ganó por penales es Harald SCHUMACHER

# %%
#EJERCICIO 3
#aca nos piden hacer un histograma de la distribucion de goles por periodo de tiempo (90' entre bins de 4')
#hay que hacer 2 graficos, uno para la fase de grupos y uno para la fase de eliminacion
#de entrada vemos que vamos a necesitar mergear ambos df

# %%
df_p3 = df_p.copy()
df_j3 = df_j.copy()

#df_p3['MatchID'].value_counts()
#df_j3.value_counts()

#hacemos el merge en la columna match id
df_3 = df_p3.merge(df_j3, how='inner', on='MatchID')[
        ['Year', 'Stage', 'Home Team Goals', 'Away Team Goals', 'MatchID', 'Player Name', 'Position', 'Event']] #filtramos xq solo queremos estas columnas


df_3
# Out:
#          Year        Stage  Home Team Goals  Away Team Goals      MatchID  \
# 0      1930.0      Group 1              4.0              1.0       1096.0
# 1      1930.0      Group 1              4.0              1.0       1096.0
# 2      1930.0      Group 1              4.0              1.0       1096.0
# 3      1930.0      Group 1              4.0              1.0       1096.0
# 4      1930.0      Group 1              4.0              1.0       1096.0
# ...       ...          ...              ...              ...          ...
# 36997  2014.0  Round of 16              2.0              1.0  300186497.0
# 36998  2014.0  Round of 16              2.0              1.0  300186497.0
# 36999  2014.0  Round of 16              2.0              1.0  300186497.0
# 37000  2014.0  Round of 16              2.0              1.0  300186497.0
# 37001  2014.0  Round of 16              2.0              1.0  300186497.0
#
#             Player Name Position Event
# 0           Alex THEPOT       GK   NaN
# 1       Oscar BONFIGLIO       GK   NaN
# 2      Marcel LANGILLER      NaN  G40'
# 3          Juan CARRENO      NaN  G70'
# 4       Ernest LIBERATI      NaN   NaN
# ...                 ...      ...   ...
# 36997          ALTIDORE      NaN   NaN
# 36998            DEFOUR      NaN   NaN
# 36999       WONDOLOWSKI      NaN  I72'
# 37000      VANDEN BORRE      NaN   NaN
# 37001          CHANDLER      NaN   NaN
#
# [37002 rows x 8 columns]

# %%
#me quedo con las filas que contienen eventos que no sean NaN
#me quedo con las filas cuyos eventos son solamente goles

df_31 = df_3[df_3['Event'].str.contains('G') & df_3['Event'].notna()]
#df_31.drop_duplicates(subset=['MatchID'], inplace=True) #nos habian quedado muchos duplicados por todos los jugadores

df_31
# Out:
#          Year        Stage  Home Team Goals  Away Team Goals      MatchID  \
# 2      1930.0      Group 1              4.0              1.0       1096.0
# 3      1930.0      Group 1              4.0              1.0       1096.0
# 6      1930.0      Group 1              4.0              1.0       1096.0
# 14     1930.0      Group 1              4.0              1.0       1096.0
# 35     1930.0      Group 4              3.0              0.0       1090.0
# ...       ...          ...              ...              ...          ...
# 36881  2014.0  Round of 16              1.0              1.0  300186459.0
# 36918  2014.0  Round of 16              1.0              0.0  300186503.0
# 36966  2014.0  Round of 16              2.0              1.0  300186497.0
# 36984  2014.0  Round of 16              2.0              1.0  300186497.0
# 36995  2014.0  Round of 16              2.0              1.0  300186497.0
#
#             Player Name Position        Event
# 2      Marcel LANGILLER      NaN         G40'
# 3          Juan CARRENO      NaN         G70'
# 6       Andre MASCHINOT      NaN    G43' G87'
# 14       Lucien LAURENT      NaN         G19'
# 35           Tom FLORIE        C         G45'
# ...                 ...      ...          ...
# 36881          SOKRATIS      NaN         G90'
# 36918          DI MARIA      NaN  G118' Y120'
# 36966         DE BRUYNE      NaN         G93'
# 36984            LUKAKU      NaN   I91' G105'
# 36995             GREEN      NaN  I105' G107'
#
# [1848 rows x 8 columns]

# %%
#aca vamos a intentar modificar el df para que solo nos aparezca el minuto de cada gol
import re

df_31['Goals in minutes'] = pd.Series(dtype=object) #creamos una columna vacia que toma objetos (le vamos a pasar listas)
for i in df_31.index:
  evento = df_31['Event'].loc[i]
  s = [s for s in re.findall(r'(?<=G)-?\d+?\d*', evento)]   #aca usamos regex para extraer los eventos de la forma 'GX' con X = minuto del gol
  df_31['Goals in minutes'].loc[i] = [] + s


df_31
# Out:
# <ipython-input-27-b7c5e30ce656>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_31['Goals in minutes'] = pd.Series(dtype=object) #creamos una columna vacia que toma objetos (le vamos a pasar listas)
# <ipython-input-27-b7c5e30ce656>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_31['Goals in minutes'].loc[i] = [] + s
#          Year        Stage  Home Team Goals  Away Team Goals      MatchID  \
# 2      1930.0      Group 1              4.0              1.0       1096.0
# 3      1930.0      Group 1              4.0              1.0       1096.0
# 6      1930.0      Group 1              4.0              1.0       1096.0
# 14     1930.0      Group 1              4.0              1.0       1096.0
# 35     1930.0      Group 4              3.0              0.0       1090.0
# ...       ...          ...              ...              ...          ...
# 36881  2014.0  Round of 16              1.0              1.0  300186459.0
# 36918  2014.0  Round of 16              1.0              0.0  300186503.0
# 36966  2014.0  Round of 16              2.0              1.0  300186497.0
# 36984  2014.0  Round of 16              2.0              1.0  300186497.0
# 36995  2014.0  Round of 16              2.0              1.0  300186497.0
#
#             Player Name Position        Event Goals in minutes
# 2      Marcel LANGILLER      NaN         G40'             [40]
# 3          Juan CARRENO      NaN         G70'             [70]
# 6       Andre MASCHINOT      NaN    G43' G87'         [43, 87]
# 14       Lucien LAURENT      NaN         G19'             [19]
# 35           Tom FLORIE        C         G45'             [45]
# ...                 ...      ...          ...              ...
# 36881          SOKRATIS      NaN         G90'             [90]
# 36918          DI MARIA      NaN  G118' Y120'            [118]
# 36966         DE BRUYNE      NaN         G93'             [93]
# 36984            LUKAKU      NaN   I91' G105'            [105]
# 36995             GREEN      NaN  I105' G107'            [107]
#
# [1848 rows x 9 columns]

# %%
df_31['Stage'].value_counts()
# Out:
# Group 2                     147
# Quarter-finals              136
# Group 1                     133
# Group 4                     128
# Group B                     128
# Group A                     124
# Round of 16                 121
# Group 3                     117
# Group C                     103
# Group D                      98
# Group E                      98
# Semi-finals                  90
# Group F                      77
# Group G                      62
# Group H                      62
# Final                        54
# Match for third place        48
# Group 6                      46
# Preliminary round            31
# First round                  31
# Group 5                       6
# Third place                   6
# Play-off for third place      2
# Name: Stage, dtype: int64

# %%
#nos creamos dos df nuevos filtrando por fase de grupos y fase de eliminatorias
df_32g = df_31.loc[df_31['Stage'].str.contains('Group')]  #fase de grupos
df_32e = df_31.loc[~df_31['Stage'].str.contains('Group')]  #fase de no grupos (elim)

#df_32e['Stage'].value_counts()
#df_32g['Stage'].value_counts()

# %%
#me armo lista con todos los minutos en los que se metieron goles, una para fase de grupo y una para not grupos
#despues con esa lista vamos a calcular las frecuencias para el histograma

#la _g es de grupos, la _e es de eliminatorias
l_goles_e = list()
for i in df_32e.index:
  goles_x_minuto = df_32e['Goals in minutes'].loc[i]
  for j in range(len(goles_x_minuto)):
    l_goles_e.append(int(goles_x_minuto[j]))

l_goles_g = list()
for i in df_32g.index:
  goles_x_minuto = df_32g['Goals in minutes'].loc[i]
  for j in range(len(goles_x_minuto)):
    l_goles_g.append(int(goles_x_minuto[j]))


#me hago un dict con key=minuto del gol, val=frecuencia en que ese gol aparece en la lista
#igual que antes, hacemos uno para fase de grupos y otra para not grupos
d_goles_e = dict()
for i in l_goles_e:
  try:
    d_goles_e[i] += 1
  except:
    d_goles_e[i] = 1


d_goles_g =dict()
for i in l_goles_g:
  try:
    d_goles_g[i] += 1
  except:
    d_goles_g[i] = 1

#d_goles_g
#d_goles_e

# %%
#esto es medio confuso pero tiene una explicacion.
#primero notamos que x el algoritmo de division entera (Algebra I):  90 = 4*22 + 2. i.e: al dividir 90 entre 4, nos sobran 2
#basicamente en este lagoritmo lo que hacemos es un ciclo que va iterando mod 4 asi que vamos obteniendo la suma de los goles en franjas de 4 minutos
#**

d_frec_goles_g, d_frec_goles_e = dict(), dict()
i = 1
while i < 86: #necesitamos 90 minutos, y restamos 4 porque el algoritmo itera en mod 4
  d_frec_goles_g[i] = d_goles_g[i] + d_goles_g[i + 1] + d_goles_g[i + 2] + d_goles_g[i + 3]
  d_frec_goles_e[i] = d_goles_e[i] + d_goles_e[i + 1] + d_goles_e[i + 2] + d_goles_e[i + 3]

  if i == 85:                                                                    #esta linea la agregamos justamente porque el ultimo bin debe tener 6 minutos para que sean 90 total
    d_frec_goles_g[i] = d_frec_goles_g[i] + d_goles_g[89] + d_goles_g[90]         #sino solo estariamos contando hasta el minuto 88
    d_frec_goles_e[i] = d_frec_goles_e[i] + d_goles_e[89] + d_goles_e[90]
  i+=4

#d_frec_goles_e
#d_frec_goles_g

# %%
#nos creamos dos df, uno con grupos y uno con elim, que muestra el minuto y la cantidad de goles por minuto (frecuencia)
#basicamente cada df es una tabla de frecuencias de goles por minuto

minuto_e = pd.Series(d_frec_goles_e.keys())
frecuencia_e = pd.Series(d_frec_goles_e.values())

minuto_g = pd.Series(d_frec_goles_g.keys())
frecuencia_g = pd.Series(d_frec_goles_g.values())

df_33e, df_33g = pd.DataFrame(), pd.DataFrame()

df_33e['Minuto'] = minuto_e
df_33e['Frecuencia'] = frecuencia_e

df_33g['Minuto'] = minuto_g
df_33g['Frecuencia'] = frecuencia_g

df_33e.sort_values('Minuto', inplace=True)
df_33g.sort_values('Minuto', inplace=True)

#df_33e
#df_33g

# %%
#y ahora ya tenemo todo para graficar

titulo = 'Graficos Ejercicio 3: Frecuencia de goles por minuto de juego'

fig, ax = plt.subplots(nrows=1, ncols = 2, figsize = (20, 7))

x_grupos = [str(i) for i in df_33g['Minuto']]
x_elim = [str(j) for j in df_33e['Minuto']]

ax[0].bar(x=x_grupos, height=df_33g['Frecuencia'])
ax[0].set_ylabel('Frecuencia de goles')
ax[0].set_xlabel('Minutos de Fase de Grupos')

ax[1].bar(x=x_elim, height=df_33e['Frecuencia'])
ax[1].set_xlabel('Minutos de Fase de Eliminación')

plt.show()

# %%
#EJERCICIO 4:

#empezamos haciendo el df_4 con los goles por partido de todos los partidos
#ya lo tenemos codeado del ejercicio anterior :D

df_4 = df_31.copy()
df_4
# Out:
#          Year        Stage  Home Team Goals  Away Team Goals      MatchID  \
# 2      1930.0      Group 1              4.0              1.0       1096.0
# 3      1930.0      Group 1              4.0              1.0       1096.0
# 6      1930.0      Group 1              4.0              1.0       1096.0
# 14     1930.0      Group 1              4.0              1.0       1096.0
# 35     1930.0      Group 4              3.0              0.0       1090.0
# ...       ...          ...              ...              ...          ...
# 36881  2014.0  Round of 16              1.0              1.0  300186459.0
# 36918  2014.0  Round of 16              1.0              0.0  300186503.0
# 36966  2014.0  Round of 16              2.0              1.0  300186497.0
# 36984  2014.0  Round of 16              2.0              1.0  300186497.0
# 36995  2014.0  Round of 16              2.0              1.0  300186497.0
#
#             Player Name Position        Event Goals in minutes
# 2      Marcel LANGILLER      NaN         G40'             [40]
# 3          Juan CARRENO      NaN         G70'             [70]
# 6       Andre MASCHINOT      NaN    G43' G87'         [43, 87]
# 14       Lucien LAURENT      NaN         G19'             [19]
# 35           Tom FLORIE        C         G45'             [45]
# ...                 ...      ...          ...              ...
# 36881          SOKRATIS      NaN         G90'             [90]
# 36918          DI MARIA      NaN  G118' Y120'            [118]
# 36966         DE BRUYNE      NaN         G93'             [93]
# 36984            LUKAKU      NaN   I91' G105'            [105]
# 36995             GREEN      NaN  I105' G107'            [107]
#
# [1848 rows x 9 columns]

# %%
#armo una funcion que me tire los indices de las filas (partidos) donde no hubo goles
def no_hubo_goles(df):
  indices = list()
  for i in range(len(df['Goals in minutes'])):
    if len(df['Goals in minutes'].iloc[i]) == 0:
      indices.append(i)

  return indices

# %%
#usamos esa funcioncita para verificar si hubo partidos sin goles
indices_sin_goles = no_hubo_goles(df_4)
indices_sin_goles

#vemos que en todos los partidos que estan en nuestro df hubo algun gol :D
#tambien lo podemos chequear haciendo un value_counts() o sortenado el df segun la columna de las listas de goles y vinedo que no hay listas vacias
#esto es por cómo armamos el df al principio del ejercicio 3 :D
# Out:
# []

# %%
df_4['Primer Gol'] = [min(df_4['Goals in minutes'].iloc[i]) for i in range(len(df_4))] # agregamos una coolumna con el minuto del primer gol

# %%
#nos armamos la lista con los datos para el primer grafico:
x1 = [int(i) for i in df_4['Primer Gol']] #al parecer la columna es de strings
x1
# Out:
# [40,
#  70,
#  43,
#  19,
#  45,
#  23,
#  69,
#  30,
#  62,
#  21,
#  1,
#  89,
#  79,
#  75,
#  81,
#  3,
#  65,
#  85,
#  60,
#  10,
#  60,
#  65,
#  53,
#  75,
#  12,
#  17,
#  65,
#  67,
#  37,
#  40,
#  30,
#  35,
#  7,
#  24,
#  15,
#  51,
#  12,
#  56,
#  69,
#  20,
#  80,
#  89,
#  20,
#  18,
#  61,
#  4,
#  89,
#  57,
#  12,
#  68,
#  37,
#  20,
#  93,
#  44,
#  18,
#  109,
#  35,
#  11,
#  31,
#  53,
#  29,
#  43,
#  69,
#  66,
#  48,
#  67,
#  4,
#  79,
#  49,
#  29,
#  66,
#  25,
#  25,
#  55,
#  29,
#  63,
#  90,
#  18,
#  20,
#  57,
#  50,
#  67,
#  11,
#  82,
#  78,
#  49,
#  18,
#  24,
#  60,
#  82,
#  44,
#  30,
#  8,
#  51,
#  11,
#  19,
#  62,
#  21,
#  1,
#  54,
#  27,
#  28,
#  95,
#  71,
#  81,
#  29,
#  43,
#  13,
#  15,
#  28,
#  35,
#  16,
#  38,
#  1,
#  105,
#  103,
#  35,
#  69,
#  88,
#  94,
#  2,
#  83,
#  44,
#  118,
#  25,
#  104,
#  111,
#  93,
#  118,
#  35,
#  51,
#  57,
#  75,
#  8,
#  64,
#  42,
#  30,
#  40,
#  89,
#  81,
#  80,
#  22,
#  84,
#  51,
#  10,
#  9,
#  63,
#  25,
#  57,
#  65,
#  37,
#  39,
#  1,
#  51,
#  87,
#  80,
#  63,
#  38,
#  44,
#  28,
#  16,
#  70,
#  8,
#  35,
#  30,
#  71,
#  65,
#  51,
#  39,
#  81,
#  89,
#  17,
#  83,
#  78,
#  34,
#  7,
#  25,
#  84,
#  70,
#  59,
#  17,
#  32,
#  3,
#  20,
#  23,
#  81,
#  17,
#  30,
#  74,
#  35,
#  26,
#  17,
#  38,
#  4,
#  69,
#  48,
#  63,
#  12,
#  23,
#  18,
#  14,
#  83,
#  87,
#  44,
#  10,
#  89,
#  32,
#  82,
#  16,
#  47,
#  54,
#  29,
#  37,
#  73,
#  39,
#  85,
#  17,
#  57,
#  71,
#  67,
#  21,
#  31,
#  40,
#  77,
#  39,
#  5,
#  33,
#  80,
#  15,
#  82,
#  79,
#  66,
#  47,
#  71,
#  84,
#  33,
#  69,
#  30,
#  23,
#  34,
#  15,
#  84,
#  52,
#  2,
#  60,
#  14,
#  18,
#  24,
#  12,
#  59,
#  75,
#  26,
#  67,
#  36,
#  5,
#  18,
#  78,
#  44,
#  54,
#  30,
#  17,
#  21,
#  3,
#  54,
#  85,
#  19,
#  69,
#  48,
#  75,
#  21,
#  77,
#  52,
#  17,
#  84,
#  25,
#  76,
#  10,
#  37,
#  18,
#  69,
#  43,
#  48,
#  81,
#  78,
#  58,
#  21,
#  30,
#  82,
#  7,
#  62,
#  12,
#  67,
#  48,
#  90,
#  14,
#  39,
#  46,
#  16,
#  5,
#  67,
#  78,
#  32,
#  25,
#  16,
#  76,
#  26,
#  17,
#  85,
#  65,
#  7,
#  4,
#  47,
#  61,
#  51,
#  31,
#  75,
#  109,
#  47,
#  12,
#  79,
#  22,
#  18,
#  10,
#  6,
#  8,
#  17,
#  13,
#  66,
#  55,
#  2,
#  32,
#  40,
#  5,
#  27,
#  24,
#  70,
#  50,
#  52,
#  20,
#  83,
#  61,
#  6,
#  49,
#  49,
#  38,
#  20,
#  32,
#  89,
#  4,
#  73,
#  24,
#  76,
#  45,
#  4,
#  16,
#  63,
#  63,
#  15,
#  70,
#  59,
#  43,
#  55,
#  3,
#  59,
#  34,
#  77,
#  3,
#  20,
#  79,
#  19,
#  19,
#  54,
#  69,
#  49,
#  20,
#  29,
#  80,
#  73,
#  12,
#  44,
#  66,
#  22,
#  16,
#  70,
#  73,
#  56,
#  8,
#  17,
#  82,
#  69,
#  68,
#  19,
#  44,
#  76,
#  33,
#  55,
#  66,
#  12,
#  49,
#  88,
#  55,
#  68,
#  44,
#  88,
#  81,
#  32,
#  24,
#  39,
#  52,
#  9,
#  83,
#  2,
#  52,
#  50,
#  84,
#  16,
#  18,
#  4,
#  68,
#  55,
#  80,
#  32,
#  75,
#  56,
#  73,
#  56,
#  4,
#  51,
#  44,
#  6,
#  51,
#  83,
#  80,
#  71,
#  17,
#  49,
#  29,
#  19,
#  67,
#  81,
#  42,
#  73,
#  87,
#  11,
#  21,
#  68,
#  76,
#  56,
#  72,
#  10,
#  90,
#  12,
#  1,
#  64,
#  70,
#  73,
#  59,
#  45,
#  89,
#  38,
#  54,
#  72,
#  35,
#  82,
#  25,
#  20,
#  82,
#  29,
#  12,
#  1,
#  2,
#  65,
#  29,
#  11,
#  26,
#  38,
#  31,
#  53,
#  13,
#  85,
#  80,
#  69,
#  48,
#  32,
#  42,
#  47,
#  90,
#  69,
#  15,
#  78,
#  17,
#  39,
#  20,
#  15,
#  15,
#  63,
#  33,
#  31,
#  62,
#  48,
#  2,
#  60,
#  90,
#  65,
#  71,
#  88,
#  8,
#  31,
#  26,
#  57,
#  75,
#  28,
#  2,
#  64,
#  14,
#  88,
#  38,
#  81,
#  57,
#  37,
#  75,
#  53,
#  81,
#  15,
#  73,
#  27,
#  42,
#  38,
#  45,
#  54,
#  15,
#  84,
#  38,
#  22,
#  32,
#  28,
#  78,
#  70,
#  11,
#  75,
#  5,
#  57,
#  46,
#  80,
#  1,
#  27,
#  25,
#  22,
#  67,
#  43,
#  88,
#  30,
#  89,
#  43,
#  89,
#  12,
#  101,
#  78,
#  50,
#  23,
#  55,
#  49,
#  73,
#  50,
#  13,
#  65,
#  10,
#  56,
#  80,
#  21,
#  61,
#  11,
#  59,
#  24,
#  12,
#  67,
#  65,
#  5,
#  52,
#  57,
#  14,
#  76,
#  86,
#  56,
#  53,
#  70,
#  12,
#  27,
#  89,
#  20,
#  59,
#  45,
#  58,
#  83,
#  90,
#  44,
#  19,
#  22,
#  84,
#  34,
#  19,
#  51,
#  40,
#  61,
#  63,
#  13,
#  70,
#  68,
#  31,
#  82,
#  108,
#  49,
#  75,
#  15,
#  70,
#  28,
#  11,
#  117,
#  44,
#  76,
#  19,
#  89,
#  98,
#  90,
#  104,
#  110,
#  8,
#  111,
#  26,
#  86,
#  71,
#  66,
#  18,
#  37,
#  18,
#  72,
#  34,
#  26,
#  7,
#  66,
#  52,
#  46,
#  79,
#  66,
#  60,
#  62,
#  8,
#  34,
#  12,
#  53,
#  69,
#  55,
#  22,
#  35,
#  65,
#  61,
#  18,
#  14,
#  30,
#  87,
#  75,
#  31,
#  18,
#  17,
#  30,
#  19,
#  88,
#  81,
#  12,
#  66,
#  79,
#  77,
#  71,
#  88,
#  55,
#  18,
#  63,
#  15,
#  46,
#  74,
#  44,
#  85,
#  38,
#  39,
#  82,
#  60,
#  25,
#  10,
#  73,
#  43,
#  35,
#  49,
#  32,
#  62,
#  43,
#  7,
#  59,
#  51,
#  24,
#  52,
#  53,
#  76,
#  76,
#  50,
#  65,
#  20,
#  14,
#  85,
#  27,
#  29,
#  76,
#  43,
#  1,
#  29,
#  54,
#  87,
#  55,
#  79,
#  15,
#  10,
#  83,
#  45,
#  37,
#  21,
#  76,
#  9,
#  14,
#  43,
#  71,
#  62,
#  60,
#  36,
#  34,
#  43,
#  44,
#  38,
#  15,
#  30,
#  73,
#  60,
#  60,
#  41,
#  22,
#  37,
#  42,
#  52,
#  56,
#  43,
#  67,
#  40,
#  75,
#  2,
#  41,
#  79,
#  44,
#  71,
#  68,
#  79,
#  82,
#  36,
#  6,
#  15,
#  16,
#  65,
#  14,
#  27,
#  3,
#  84,
#  70,
#  75,
#  50,
#  66,
#  19,
#  68,
#  12,
#  45,
#  57,
#  21,
#  50,
#  43,
#  67,
#  72,
#  64,
#  38,
#  115,
#  105,
#  82,
#  62,
#  75,
#  88,
#  34,
#  50,
#  23,
#  4,
#  11,
#  69,
#  70,
#  64,
#  64,
#  54,
#  18,
#  29,
#  73,
#  79,
#  68,
#  67,
#  54,
#  83,
#  1,
#  24,
#  7,
#  22,
#  57,
#  18,
#  83,
#  60,
#  26,
#  28,
#  76,
#  48,
#  33,
#  18,
#  63,
#  87,
#  19,
#  68,
#  24,
#  48,
#  57,
#  90,
#  83,
#  62,
#  10,
#  66,
#  55,
#  67,
#  89,
#  31,
#  75,
#  43,
#  48,
#  9,
#  60,
#  55,
#  68,
#  58,
#  61,
#  83,
#  76,
#  76,
#  27,
#  59,
#  86,
#  84,
#  15,
#  61,
#  60,
#  54,
#  70,
#  28,
#  64,
#  31,
#  35,
#  73,
#  66,
#  10,
#  27,
#  47,
#  39,
#  26,
#  67,
#  57,
#  83,
#  50,
#  27,
#  68,
#  48,
#  75,
#  66,
#  11,
#  89,
#  50,
#  75,
#  82,
#  75,
#  33,
#  46,
#  12,
#  25,
#  68,
#  22,
#  92,
#  17,
#  108,
#  98,
#  102,
#  46,
#  13,
#  44,
#  40,
#  72,
#  83,
#  69,
#  57,
#  81,
#  85,
#  43,
#  79,
#  62,
#  66,
#  2,
#  4,
#  80,
#  73,
#  46,
#  18,
#  59,
#  6,
#  23,
#  39,
#  45,
#  75,
#  35,
#  57,
#  4,
#  84,
#  34,
#  62,
#  53,
#  11,
#  70,
#  75,
#  2,
#  66,
#  2,
#  18,
#  47,
#  3,
#  85,
#  68,
#  59,
#  16,
#  41,
#  11,
#  52,
#  88,
#  18,
#  22,
#  50,
#  62,
#  29,
#  84,
#  58,
#  74,
#  62,
#  83,
#  17,
#  76,
#  3,
#  30,
#  50,
#  59,
#  54,
#  62,
#  19,
#  79,
#  14,
#  15,
#  42,
#  15,
#  70,
#  62,
#  56,
#  77,
#  110,
#  27,
#  102,
#  61,
#  34,
#  42,
#  79,
#  55,
#  15,
#  57,
#  88,
#  31,
#  56,
#  43,
#  17,
#  41,
#  35,
#  85,
#  51,
#  81,
#  9,
#  90,
#  51,
#  11,
#  27,
#  104,
#  ...]

# %%
#ahora agregamos la columna con las diferencias inter goles,
#para esto vamos a necesitar una funcion que lo haga
#y una nueva columna de listas

df_4['DT Goles'] = pd.Series(dtype=object) #le ponemos DT porque no tengo el simbolo delta

# %%
#Definimos la funcion que va a llenar la columna DT goles con las diferencias entre los tiempos de goles

def calculo_diferencias(df):
  for i in range(len(df)):  #iteramos i sobre la longitud de filas del df
    l_dt = list()
    l_gol = df['Goals in minutes'].iloc[i]

    for j in range(len(l_gol)-1):  #si tenemos un solo gol no entra en este ciclo, por lo que le termina asignando una lista vacia
      dif = int(l_gol[j+1])-int(l_gol[j])
      l_dt.append(dif)

    df['DT Goles'].iloc[i] = l_dt   #aca asignamos en cada fila lo que corresponda

  return None #void

# %%
calculo_diferencias(df_4)

df_4
# Out:
# <ipython-input-40-fb9daee41152>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DT Goles'].iloc[i] = l_dt   #aca asignamos en cada fila lo que corresponda
#          Year        Stage  Home Team Goals  Away Team Goals      MatchID  \
# 2      1930.0      Group 1              4.0              1.0       1096.0
# 3      1930.0      Group 1              4.0              1.0       1096.0
# 6      1930.0      Group 1              4.0              1.0       1096.0
# 14     1930.0      Group 1              4.0              1.0       1096.0
# 35     1930.0      Group 4              3.0              0.0       1090.0
# ...       ...          ...              ...              ...          ...
# 36881  2014.0  Round of 16              1.0              1.0  300186459.0
# 36918  2014.0  Round of 16              1.0              0.0  300186503.0
# 36966  2014.0  Round of 16              2.0              1.0  300186497.0
# 36984  2014.0  Round of 16              2.0              1.0  300186497.0
# 36995  2014.0  Round of 16              2.0              1.0  300186497.0
#
#             Player Name Position        Event Goals in minutes Primer Gol  \
# 2      Marcel LANGILLER      NaN         G40'             [40]         40
# 3          Juan CARRENO      NaN         G70'             [70]         70
# 6       Andre MASCHINOT      NaN    G43' G87'         [43, 87]         43
# 14       Lucien LAURENT      NaN         G19'             [19]         19
# 35           Tom FLORIE        C         G45'             [45]         45
# ...                 ...      ...          ...              ...        ...
# 36881          SOKRATIS      NaN         G90'             [90]         90
# 36918          DI MARIA      NaN  G118' Y120'            [118]        118
# 36966         DE BRUYNE      NaN         G93'             [93]         93
# 36984            LUKAKU      NaN   I91' G105'            [105]        105
# 36995             GREEN      NaN  I105' G107'            [107]        107
#
#       DT Goles
# 2           []
# 3           []
# 6         [44]
# 14          []
# 35          []
# ...        ...
# 36881       []
# 36918       []
# 36966       []
# 36984       []
# 36995       []
#
# [1848 rows x 11 columns]

# %%
x2 = list()

for i in range(len(df_4)):               #aca nos creamos el espacio donde vamos a calcular las frecuencias para el histograma 2
  lista_difs = df_4['DT Goles'].iloc[i]
  for j in range(len(lista_difs)):
    x2.append(lista_difs[j])

# %%
#x1
#x2
#y ya tenemos todo para graficar :D

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20,7))

ax[0].hist(x1, bins=30, width = 1.8, color='g', density=True)
ax[0].set_xlabel('Tiempo transcurrido hasta el primer gol')
ax[0].set_ylabel('Frecuencia')
ax[0].set_title('Grafico Ejercicio 4a')


ax[1].hist(x2, bins=30, width=1.8, color='r', density=True)
ax[1].set_xlabel('Diferencias de minutos entre goles')
ax[1].set_ylabel('Frecuencia')
ax[1].set_title('Grafico Ejercicio 4b')

plt.show()
